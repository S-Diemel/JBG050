# %%
pip uninstall scipy
# Out:
# Found existing installation: scipy 1.7.3
# Uninstalling scipy-1.7.3:
#   Would remove:
#     /usr/local/lib/python3.7/dist-packages/scipy-1.7.3.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/scipy.libs/libgfortran-2e0d59d6.so.5.0.0
#     /usr/local/lib/python3.7/dist-packages/scipy.libs/libopenblasp-r0-2d23e62b.3.17.so
#     /usr/local/lib/python3.7/dist-packages/scipy.libs/libquadmath-2d0c479f.so.0.0.0
#     /usr/local/lib/python3.7/dist-packages/scipy/*
# Proceed (y/n)? y
#   Successfully uninstalled scipy-1.7.3

# %%
pip install scipy
# Out:
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (1.7.3)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in /usr/local/lib/python3.7/dist-packages (from scipy) (1.21.5)

# %%
pip install pmdarima
# Out:
# Traceback (most recent call last):

# %% [markdown]
# # Restart kernel before executing

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_absolute_error
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

from sklearn.metrics import r2_score
from statsmodels.tsa.stattools import adfuller
from pmdarima import auto_arima
from statsmodels.tsa.arima_model import ARIMA
#Ignore warnings
import warnings
import scipy
from datetime import datetime
from platform import python_version
import statsmodels.api as sm
import matplotlib.dates as mdates
print(python_version())
warnings.filterwarnings('ignore')
# Out:
# 3.7.13

# %%
burg = 'burglarys city'
col = burg
n_periods = 12
city = 'Blackpool'
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv("/content/drive/MyDrive/Data Challenge 2/data/final_burglary_data_city1.csv")
print(sorted(df['city'].unique()))
df['year month'] = [datetime.strptime(date, '%Y-%m') for date in df['year month']]
df_city = df.loc[df['city'] == city]
# Reset index to stop expected value error

df_city_index_reset = df_city.reset_index(drop = True)

#Sort it on year/month to perform ARIMA
df_city_sorted = df_city_index_reset.set_index(df_city_index_reset['year month'])

#Create test partition
df_city_train = df_city_sorted['2010-12':'2017-12']
df_city_test  = df_city_sorted['2017-12':'2019-12']
plot_acf(df_city_train[col].dropna())
plot_pacf(df_city_train[col].dropna())

smodel = auto_arima(df_city_train[col].dropna(), start_p=1, start_q=1,
                    test='adf',
                    max_p=3, max_q=3, m=12,
                    start_P=0, seasonal=True,
                    d=0, D=1, trace=True,
                    error_action='ignore',
                    suppress_warnings=True,
                    stepwise=True)
print(smodel.summary())

fitted, confint = smodel.predict(n_periods=n_periods, return_conf_int=True)
index_of_fc = df_city_test.index[:n_periods]

# make series for plotting purpose
fitted_series = pd.Series(fitted, index=index_of_fc)
lower_series = pd.Series(confint[:, 0], index=index_of_fc)
upper_series = pd.Series(confint[:, 1], index=index_of_fc)

smodel.plot_diagnostics(figsize=(14, 14))
plt.show()

# Plot
plt.plot(df_city_train[col].dropna())
plt.plot(df_city_test[col][:n_periods].dropna())
plt.plot(fitted_series, color='darkgreen')
plt.fill_between(lower_series.index,
                 lower_series,
                 upper_series,
                 color='k', alpha=.15)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gcf().autofmt_xdate()
plt.title("SARIMA - Forecast")
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ['Adur', 'Allerdale', 'Amber Valley', 'Arun', 'Ashfield', 'Ashford', 'Aylesbury Vale', 'Babergh', 'Barking and Dagenham', 'Barnet', 'Barnsley', 'Barrow-in-Furness', 'Basildon', 'Basingstoke and Deane', 'Bassetlaw', 'Bath and North East Somerset', 'Bedford', 'Bexley', 'Birmingham', 'Blaby', 'Blackburn with Darwen', 'Blackpool', 'Blaenau Gwent', 'Bolsover', 'Bolton', 'Boston', 'Bournemouth', 'Bracknell Forest', 'Bradford', 'Braintree', 'Breckland', 'Brent', 'Brentwood', 'Bridgend', 'Brighton and Hove', 'Bristol', 'Broadland', 'Bromley', 'Bromsgrove', 'Broxbourne', 'Broxtowe', 'Burnley', 'Bury', 'Caerphilly', 'Calderdale', 'Cambridge', 'Camden', 'Cannock Chase', 'Canterbury', 'Cardiff', 'Carlisle', 'Carmarthenshire', 'Castle Point', 'Central Bedfordshire', 'Ceredigion', 'Charnwood', 'Chelmsford', 'Cheltenham', 'Cherwell', 'Cheshire East', 'Cheshire West and Chester', 'Chesterfield', 'Chichester', '
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,1,1)[12] intercept   : AIC=709.645, Time=1.03 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=749.951, Time=0.02 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=719.406, Time=0.84 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=inf, Time=1.40 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=747.957, Time=0.04 sec
#  ARIMA(1,0,1)(0,1,0)[12] intercept   : AIC=725.277, Time=0.37 sec
#  ARIMA(1,0,1)(1,1,1)[12] intercept   : AIC=711.531, Time=1.37 sec
#  ARIMA(1,0,1)(0,1,2)[12] intercept   : AIC=711.519, Time=1.04 sec
#  ARIMA(1,0,1)(1,1,0)[12] intercept   : AIC=716.783, Time=0.46 sec
#  ARIMA(1,0,1)(1,1,2)[12] intercept   : AIC=inf, Time=2.31 sec
#  ARIMA(1,0,0)(0,1,1)[12] intercept   : AIC=710.402, Time=0.31 sec
#  ARIMA(2,0,1)(0,1,1)[12] intercept   : AIC=711.377, Time=0.67 sec
#  ARIMA(1,0,2)(0,1,1)[12] intercept   : AIC=711.348, Time=0.62 sec
#  ARIMA(0,0,0)(0,1,1)[12] intercept   : AIC=inf, Time=0.36 sec
#  ARIMA(0,0,2)(0,1,1)[12] intercept   : AIC=712.711, Time=0.68 sec
#  ARIMA(2,0,0)(0,1,1)[12] intercept   : AIC=709.436, Time=0.45 sec
#  ARIMA(2,0,0)(0,1,0)[12] intercept   : AIC=723.661, Time=0.19 sec
#  ARIMA(2,0,0)(1,1,1)[12] intercept   : AIC=711.324, Time=0.67 sec
#  ARIMA(2,0,0)(0,1,2)[12] intercept   : AIC=711.323, Time=1.05 sec
#  ARIMA(2,0,0)(1,1,0)[12] intercept   : AIC=715.008, Time=0.46 sec
#  ARIMA(2,0,0)(1,1,2)[12] intercept   : AIC=inf, Time=2.43 sec
#  ARIMA(3,0,0)(0,1,1)[12] intercept   : AIC=711.390, Time=0.57 sec
#  ARIMA(3,0,1)(0,1,1)[12] intercept   : AIC=713.377, Time=1.30 sec
#  ARIMA(2,0,0)(0,1,1)[12]             : AIC=707.455, Time=0.28 sec
#  ARIMA(2,0,0)(0,1,0)[12]             : AIC=721.670, Time=0.06 sec
#  ARIMA(2,0,0)(1,1,1)[12]             : AIC=709.343, Time=0.82 sec
#  ARIMA(2,0,0)(0,1,2)[12]             : AIC=709.342, Time=0.70 sec
#  ARIMA(2,0,0)(1,1,0)[12]             : AIC=713.030, Time=0.16 sec
#  ARIMA(2,0,0)(1,1,2)[12]             : AIC=inf, Time=2.28 sec
#  ARIMA(1,0,0)(0,1,1)[12]             : AIC=708.547, Time=0.22 sec
#  ARIMA(3,0,0)(0,1,1)[12]             : AIC=709.405, Time=0.43 sec
#  ARIMA(2,0,1)(0,1,1)[12]             : AIC=709.392, Time=0.53 sec
#  ARIMA(1,0,1)(0,1,1)[12]             : AIC=707.662, Time=0.35 sec
#  ARIMA(3,0,1)(0,1,1)[12]             : AIC=711.391, Time=0.66 sec
#
# Best model:  ARIMA(2,0,0)(0,1,1)[12]
# Total fit time: 25.212 seconds
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                   85
# Model:             SARIMAX(2, 0, 0)x(0, 1, [1], 12)   Log Likelihood                -349.727
# Date:                              Mon, 04 Apr 2022   AIC                            707.455
# Time:                                      16:55:14   BIC                            716.616
# Sample:                                           0   HQIC                           711.106
#                                                - 85
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3688      0.108      3.430      0.001       0.158       0.580
# ar.L2          0.2150      0.116      1.857      0.063      -0.012       0.442
# ma.S.L12      -0.6972      0.204     -3.420      0.001      -1.097      -0.298
# sigma2       758.9750    186.557      4.068      0.000     393.329    1124.621
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 1.43
# Prob(Q):                              0.99   Prob(JB):                         0.49
# Heteroskedasticity (H):               0.59   Skew:                             0.01
# Prob(H) (two-sided):                  0.20   Kurtosis:                         2.32
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
print('MAE:', mean_absolute_error(df_city_test[col][:n_periods].dropna(), fitted_series))
print("R2:", r2_score(df_city_test[col][:n_periods].dropna(), fitted_series))
# Out:
# MAE: 11.395661646855963
# R2: 0.22074336388887195

# %%
def ad_test(dataset):
  df_city_test = adfuller(dataset, autolag = 'AIC')
  print('1. ADF: ',df_city_test[0])
  print('2. P-value: ',df_city_test[1])
  print('3. Num of Lags: ',df_city_test[2])
  print('4. Num of observations for ADF REgressiom and Critical Values Calculation :',df_city_test[3])
  print('5. Critical values: ')
  for key, val in df_city_test[4].items():
    print('\t',key,':', val)

# %%
ad_test(df_city_test['burglarys city'])
# Out:
# 1. ADF:  -1.458700376108602
# 2. P-value:  0.5538338602554045
# 3. Num of Lags:  9
# 4. Num of observations for ADF REgressiom and Critical Values Calculation : 15
# 5. Critical values:
# 	 1% : -3.9644434814814815
# 	 5% : -3.0849081481481484
# 	 10% : -2.6818144444444445
