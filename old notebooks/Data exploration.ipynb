# %%
import numpy as np
import pandas as pd
import re
from tqdm import tqdm
import datetime as datetime

# %% [markdown]
# # Outcomes data

# %%
df_outcomes = pd.read_csv(r"C:\Users\20203721\Documents\Data Challenge 2\Data description\2019 - 2021 all data\2019-01\2019-01-avon-and-somerset-outcomes.csv")

# %%
df_outcomes.describe(include="all")
# Out:
#                                                  Crime ID    Month  \
# count                                                2915     2915
# unique                                               2550        1
# top     5dff116e940f3fa4fcd9406fd4ec5cbba6d67419da8663...  2019-01
# freq                                                    8     2915
# mean                                                  NaN      NaN
# std                                                   NaN      NaN
# min                                                   NaN      NaN
# 25%                                                   NaN      NaN
# 50%                                                   NaN      NaN
# 75%                                                   NaN      NaN
# max                                                   NaN      NaN
#
#                            Reported by                    Falls within  \
# count                             2915                            2915
# ...

# %%
df_outcomes.head()
# Out:
#                                             Crime ID    Month  \
# 0  78040516850e7777c41f53736ce5b91629f962eb1e11be...  2019-01
# 1  3acdf6262249ece2a458507b16340840f9f7c2fc565e75...  2019-01
# 2  fbfe5fbb589cc6129278e80434c5e392e25254c6af0491...  2019-01
# 3  08906ba76906e627b949954e4394b4c44c302d51e777df...  2019-01
# 4  992ec9c65bf8cace7709c0f16cd956bccd5d05350b6474...  2019-01
#
#                       Reported by                    Falls within  Longitude  \
# 0  Avon and Somerset Constabulary  Avon and Somerset Constabulary        NaN
# 1  Avon and Somerset Constabulary  Avon and Somerset Constabulary        NaN
# 2  Avon and Somerset Constabulary  Avon and Somerset Constabulary        NaN
# 3  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.599081
# 4  Avon and Somerset Constabulary  Avon and Somerset Constabulary        NaN
#
#     Latitude                   Location  LSOA code     LSOA name  \
# ...

# %% [raw]
# Crime ID - integer
# Month - month in which crime was committed (YYYY-MM)
# Reported by - The force that provided the data about the crime.
# Falls within - The force that provided the data about the crime
# Longitude - longitude of the crime (anonymised)
# Latitude - latitude of the crime (anonymised)
# Location - describes location where the crime occured.
# LSOA code - The Lower Layer Super Output Area code that the anonymised point falls into.
# LSOA name - The Lower Layer Super Output Area name that the anonymised point falls into.
# Outcome type - Outcome of the crime. Newly added data is always empty.

# %% [markdown]
# # Stop and search data

# %%
df_s_and_s = pd.read_csv(r"C:\Users\20203721\Documents\Data Challenge 2\Data description\2019 - 2021 all data\2019-01\2019-01-avon-and-somerset-stop-and-search.csv", parse_dates = ['Date'])

# %%
df_s_and_s.describe(include='all')
# Out:
# C:\Users\20203721\AppData\Local\Temp/ipykernel_756/1251298788.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df_s_and_s.describe(include='all')
#                  Type                       Date  \
# count             519                        519
# unique              3                        400
# top     Person search  2019-01-05 23:00:00+00:00
# freq              374                          7
# first             NaN  2019-01-01 00:00:00+00:00
# last              NaN  2019-01-31 23:42:00+00:00
# mean              NaN                        NaN
# std               NaN                        NaN
# min               NaN                        NaN
# 25%               NaN                        NaN
# 50%               NaN                        NaN
# ...

# %%
df_s_and_s.head()
# Out:
#             Type                       Date  Part of a policing operation  \
# 0  Person search  2019-01-01T00:00:00+00:00                           NaN
# 1  Person search  2019-01-01T00:00:00+00:00                           NaN
# 2  Person search  2019-01-01T00:30:00+00:00                           NaN
# 3  Person search  2019-01-01T01:35:00+00:00                           NaN
# 4  Person search  2019-01-01T01:35:00+00:00                           NaN
#
#    Policing operation   Latitude  Longitude Gender Age range  \
# 0                 NaN        NaN        NaN   Male     18-24
# 1                 NaN        NaN        NaN   Male     10-17
# 2                 NaN  51.350977  -2.979701   Male   over 34
# 3                 NaN  51.471129  -2.589816   Male   over 34
# 4                 NaN  51.471129  -2.589816   Male   over 34
#
#                               Self-defined ethnicity  \
# 0                                                NaN
# ...
