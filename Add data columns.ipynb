# %%
import pandas as pd
import datetime

# %%
df = pd.read_csv(r"C:\Users\20203721\Documents\Data Challenge 2\all_search.csv", index_col=0)
# Out:
# C:\Users\20203721\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\20203721\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py:583: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
df.head()
# Out:
#             Type                       Date Part of a policing operation  \
# 0  Person search  2014-03-31T23:05:00+00:00                          NaN
# 1  Person search  2014-03-31T23:05:00+00:00                          NaN
# 2  Person search  2014-03-31T23:05:00+00:00                          NaN
# 3  Person search  2014-03-31T23:05:00+00:00                          NaN
# 4  Person search  2014-03-31T23:05:00+00:00                          NaN
#
#   Policing operation   Latitude  Longitude Gender Age range  \
# 0                NaN        NaN        NaN   Male     25-34
# 1                NaN  50.844310  -1.067920   Male     18-24
# 2                NaN  50.844310  -1.067920   Male     18-24
# 3                NaN  50.813747  -1.078507   Male   over 34
# 4                NaN  50.844310  -1.067920   Male     18-24
#
#        Self-defined ethnicity Officer-defined ethnicity  \
# 0             Not Stated (NS)                     Other
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Day of Week'] = df['Date'].dt.dayofweek + 1

# %%
df.head()
# Out:
#             Type                      Date Part of a policing operation  \
# 0  Person search 2014-03-31 23:05:00+00:00                          NaN
# 1  Person search 2014-03-31 23:05:00+00:00                          NaN
# 2  Person search 2014-03-31 23:05:00+00:00                          NaN
# 3  Person search 2014-03-31 23:05:00+00:00                          NaN
# 4  Person search 2014-03-31 23:05:00+00:00                          NaN
#
#   Policing operation   Latitude  Longitude Gender Age range  \
# 0                NaN        NaN        NaN   Male     25-34
# 1                NaN  50.844310  -1.067920   Male     18-24
# 2                NaN  50.844310  -1.067920   Male     18-24
# 3                NaN  50.813747  -1.078507   Male   over 34
# 4                NaN  50.844310  -1.067920   Male     18-24
#
#        Self-defined ethnicity Officer-defined ethnicity  \
# 0             Not Stated (NS)                     Other
# ...

# %%
df.to_csv(r'C:\Users\20203721\Documents\Data Challenge 2\all_search.csv', index=False)
